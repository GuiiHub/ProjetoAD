# %%
import pandas as pd

file = r'data\raw\restaurante-cafeteria-bar-e-similares-1-trimestre-2026.xlsx'

df = pd.read_excel(file)

df.head()
# Out:
#     Categoria  CNPJ Nome do Estabelecimento   UF      Cidade  \
# 0  Hospedagem    -        CAMPING SAO PEDRO   MG  DIAMANTINA
# 1         NaN  2020     14/02/2020 15:50:50  NaN         NaN
# 2  Hospedagem    -        CAMPING SAO PEDRO   MG  DIAMANTINA
# 3         NaN  2020     14/02/2020 15:50:50  NaN         NaN
# 4  Hospedagem    -        CAMPING SAO PEDRO   MG  DIAMANTINA
#
#                                             Endereço Email  \
# 0  Final Rua Carmélias, S/N, Diamantina - MG, 391...    -
# 1                                                NaN   NaN
# 2  Final Rua Carmélias, S/N, Diamantina - MG, 391...    -
# 3                                                NaN   NaN
# 4  Final Rua Carmélias, S/N, Diamantina - MG, 391...    -
#
#    Nota de Estabelecimento    Perspectiva Acessibilidade  \
# 0                      0.0            DEFICIÊNCIA VISUAL
# 1                      NaN                           NaN
# 2                      0.0            DEFICIÊNCIA VISUAL
# ...
