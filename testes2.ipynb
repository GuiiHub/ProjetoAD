# %%
import pandas as pd

file = r'data\raw\prestadorespecializadoemsegmentosturisticos2015cadasturpj.csv'

df = pd.read_csv(file,encoding='latin1',sep=';')

df.head()
# Out:
#                             RAZÃO SOCIAL                        NOME FANTASIA  \
# 0            22 MARKETING E EVENTOS LTDA                               22 MKT
# 1    3 A MULTIMIDIA E SISTEMAS LTDA - ME  3 A MULTIMIDIA E SISTEMAS LTDA - ME
# 2  3MILENIUM PROPAGANDA E MARKETING LTDA                   TRILHA COMUNICAÇÃO
# 3                          A A SIMOES ME           SID CIGANO CIA DE RODEIOS
# 4                   A D MORATO HOSTEL ME                      BRASILIA LIVING
#
#                  CNPJ                NATUREZA JURIDICA DATA INICIO OPERAÇÃO  \
# 0  11.880.503/0001-15             Sociedade Empresária                  NaN
# 1  00.311.433/0001-68             Sociedade Empresária                  NaN
# 2  37.025.012/0001-80             Sociedade Empresária           01/10/1991
# 3  13.612.464/0001-09  Empresário Individual (Não MEI)                  NaN
# 4  07.538.845/0001-84  Empresário Individual (Não MEI)                  NaN
#
# ...
