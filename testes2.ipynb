# %%
import pandas as pd

file = r'data\raw\2011-2016-tce.csv'

df = pd.read_csv(file,encoding='latin1',sep=';')

df.head()
# Out:
#     ANO                                          PROCESSO   \
# 0  2016                               72031.000654/2012-29
# 1  2016                               72031.000499/2016-74
# 2  2016                               72031.000498/2016-20
# 3  2016                               72031.000500/2016-61
# 4  2016   72031.000313/2016-87                         ...
#
#                                           CONVENENTE SIAFI/SICONV   CONVÊNIO  \
# 0  Instituto Sul-Americano de Desenvolvimento Sus...       747124  1405/2010
# 1                              Município de Macarani       732163  0111/2010
# 2  Sociedade Goiana de Pecuária e Agricultura - SGPA       707037  1180/2009
# 3                       Município de Lagoa dos Patos       739363  0963/2010
# 4                                 Município de Bugre       704155  0720/2009
#
#                  OFÍCIO DA AECI ENTREGUE NO TCU
# 0  Ofício n° 602/2016/AECI/MTur      24/05/2016
# 1  Ofício n° 604/2016/AECI/MTur      24/05/2016
# ...
