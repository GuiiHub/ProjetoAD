# %%
import pandas as pd

file = r'data\raw\operacoes-de-financiamento-fungetur-26.csv'

df = pd.read_csv(file,sep=';',encoding='latin1')

df.head()
# Out:
#                                    Agente Financeiro  CPF/CNPJ do Contratante  \
# 0  AGENCIA DE FOMENTO DO ESTADO DO RIO DE JANEIRO...             5.966099e+13
# 1                    AGENCIA DE FOMENTO DO AMAPA S/A             4.469021e+13
# 2                    AGENCIA DE FOMENTO DO AMAPA S/A             1.975056e+13
# 3                    AGENCIA DE FOMENTO DE GOIAS S/A             2.996130e+13
# 4              CRESOL BRASIL - CRESOL CENTRAL BRASIL             4.489833e+13
#
#         Nome / Razão Social  UF       Município  Valor Contratado   \
# 0       REELS BUSINESS LTDA  RJ  RIO DE JANEIRO           R$ 1,00
# 1  PEIXES & CRUSTACEOS LTDA  AP          MACAPÁ     R$ 350.000,00
# 2             REALLIZA LTDA  AP          MACAPÁ     R$ 500.000,00
# 3     AGRO SERRA VERDE LTDA  GO         IPAMERI   R$ 1.571.900,17
# 4      USINAGEM ARAUJO LTDA  SC      ITAIÓPOLIS     R$ 100.000,00
#
#   Data Início do Contrato Data Fim do Contrato  Prazo (Meses)  \
# ...
