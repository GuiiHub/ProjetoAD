# %%
import pandas as pd

file = r'data\raw\2015-indcompetitividade.csv'

df = pd.read_csv(file,sep=';',encoding='latin1')

df.head()
# Out:
#    UF                    DESTINO           TIPO ï¿½ndice Geral Infraestrutura  \
# 0  GO  Alto Paraï¿½so de Goiï¿½s  Nï¿½o capital           45,2           62,9
# 1  RJ             Angra dos Reis  Nï¿½o capital           59,9             63
# 2  SE                    Aracaju        Capital             64           81,3
# 3  CE                    Aracati  Nï¿½o capital             48           58,1
# 4  RJ   Armaï¿½ï¿½o dos Bï¿½zios  Nï¿½o capital             52           56,8
#
#   Acesso Serviï¿½o e Equipamento Atrativos Marketing Polï¿½ticas Pï¿½blicas  \
# 0   42,9                    36,7        61      31,1                   50,8
# 1   60,3                    62,6      62,9      49,4                   60,4
# 2     70                    67,8      57,6      47,9                   60,4
# 3   40,4                    41,8      58,3        35                   49,8
# 4   44,2                    61,5        58      46,8                   63,1
#
# ...
