# %%
import pandas as pd

file = r'data\raw\restaurante-cafeteria-bar-e-similares-1-trimestre-2026.xlsx'

df = pd.read_excel(file)

df.head()
# Out:
#                        Atividade Turística  Número de Inscrição do CNPJ  \
# 0  Restaurante, Cafeteria, Bar e Similares                   5858000149
# 1  Restaurante, Cafeteria, Bar e Similares                   6453000125
# 2  Restaurante, Cafeteria, Bar e Similares                  21776000198
# 3  Restaurante, Cafeteria, Bar e Similares                  52076000160
# 4  Restaurante, Cafeteria, Bar e Similares                  56231000117
#
#                              Nome da Pessoa Jurídica  \
# 0                 ITABERABA POINT SUPER LANCHES LTDA
# 1                    RIPA NA BRASA RESTAURANTE LTDA.
# 2                  GIOVANNI POINT SUPER LANCHES LTDA
# 3                            POPULAR LANCHONETE LTDA
# 4  BLASON EMPREENDIMENTOS PARTICIPACOES E CONSULT...
#
#                              Nome Fantasia Situação Cadastral  \
# 0                          ITABERABA POINT            Regular
# 1                RIPA NA BRASA RESTAURANTE            Regular
# ...
